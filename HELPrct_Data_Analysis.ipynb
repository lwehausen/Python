# %% [markdown]
# <a href="https://colab.research.google.com/github/lwehausen/Python/blob/main/HELPrct_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A data analysis and data visualization using the HELPrct data set and mosaic dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import axes

# %%
HELPrct = pd.read_csv("https://raw.githubusercontent.com/gjm112/DSCI401/main/data/HELPrct.csv")

# %% [markdown]
# Let's take a look at the data:

# %%
HELPrct.head(1)
# Out:
#    age  anysubstatus anysub  cesd  d1  daysanysub  dayslink  drugrisk  e2b  \
# 0   37           1.0    yes    49   3       177.0     225.0       0.0  NaN
#
#    female  ...        pcs pss_fr racegrp  satreat  sexrisk  substance  treat  \
# 0       0  ...  58.413689      0   black       no        4    cocaine    yes
#
#    avg_drinks max_drinks  hospitalizations
# 0          13         26                 3
#
# [1 rows x 30 columns]

# %% [markdown]
# Use the HELPrct data from the mosaicData to calculate the mean
# of all numeric variables (be sure to exclude missing values).

# %%
#Calculate the mean of numeric variables
HELPrct.mean()
# Out:
# <ipython-input-9-909728dd3df7>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   HELPrct.mean()
# age                  35.653422
# anysubstatus          0.772358
# cesd                 32.847682
# d1                    3.059603
# daysanysub           75.307377
# dayslink            255.605568
# drugrisk              1.887168
# e2b                   2.504673
# female                0.236203
# i1                   17.907285
# i2                   24.547461
# id                  233.401766
# indtot               35.728477
# linkstatus            0.378190
# mcs                  31.676678
# pcs                  48.048542
# pss_fr                6.706402
# sexrisk               4.642384
# avg_drinks           17.907285
# max_drinks           24.547461
# ...

# %% [markdown]
# Find the mean of all the numeric variables stratified by sex and age
# group where age groups are defined as ranges of 10 years (i.e. 0-10,
# 10-20, 20-30, etc).

# %%
#Create the 10 year age groups and group by sex.
HELPrct["age_groups"] = pd.cut(x=HELPrct["age"], bins=[0, 10, 20, 30, 40, 50, 60])
#Find the mean of all numeric variables:
help = HELPrct.groupby(["sex", "age_groups"]).mean().dropna()
help
# Out:
# <ipython-input-10-5c65a68db1ff>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   help = HELPrct.groupby(["sex", "age_groups"]).mean().dropna()
#                          age  anysubstatus       cesd        d1  daysanysub  \
# sex    age_groups
# female (20, 30]    27.086957      0.769231  38.652174  2.304348   67.153846
#        (30, 40]    34.982456      0.730769  36.596491  3.631579   91.769231
#        (40, 50]    45.500000      0.600000  35.583333  4.333333   85.666667
#        (50, 60]    56.666667      0.666667  39.333333  3.000000   77.000000
# male   (10, 20]    19.666667      1.000000  38.666667  1.000000   98.500000
#        (20, 30]    26.711111      0.785714  32.211111  1.933333   77.928571
#        (30, 40]    35.143713      0.789474  30.550898  2.568862   73.627660
# ...

# %% [markdown]
# Using the data set created in the previous problem, create a set of line
# plots with the average age of the age group on the x-axis and each of
# other numeric variables on the y-axis (in separate plots, obviously!)
# stratified by sex.

# %%
p = help.groupby("sex").plot.line(subplots=True, figsize = (12,6))

plt.subplots_adjust(wspace=0.3, hspace = 0.3)

plt.show()
